# %% [markdown]
# <a href="https://colab.research.google.com/github/lemonredwood/semantic-segmentation/blob/main/frame_extraction.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# !pip install opencv-python-headless

# %%
# !pip install -q kaggle

# %%
# !mkdir ~/.kaggle

# %%
# !cp kaggle.json ~/.kaggle/

# %%
# !chmod 600 ~/.kaggle/kaggle.json

# %%
# !kaggle datasets download -d zeadomar/football-live-match-object-detection-annotated
# Out:
# ...
#  87% 48.0M/55.0M [00:00<00:00, 214MB/s]
# 100% 55.0M/55.0M [00:00<00:00, 202MB/s]

# %%
# !unzip football-live-match-object-detection-annotated.zip -d trial
# Out:
# Archive:  football-live-match-object-detection-annotated.zip
#   inflating: trial/Annotated/test/images/ezgif-frame-004_png.rf.356d7e9068e813225b86175ee70b9b8d.jpg
#   inflating: trial/Annotated/test/images/ezgif-frame-011_png.rf.72e674fb0ccf1942012d24bee6f84581.jpg
#   inflating: trial/Annotated/test/images/ezgif-frame-017_png.rf.113e45e9672a2990cb1b6e867f47da74.jpg
#   inflating: trial/Annotated/test/images/ezgif-frame-026_png.rf.4f29280eb87925b2cd5697bc733884f7.jpg
#   inflating: trial/Annotated/test/images/ezgif-frame-038_png.rf.ec5a1fd6afc7e8c995f701ed60b19c4d.jpg
#   inflating: trial/Annotated/test/images/ezgif-frame-050_png.rf.9007f26c142acf801b11d2f2938ea54e.jpg
#   inflating: trial/Annotated/test/images/ezgif-frame-054_png.rf.1bc2e5799d7b0c81f62f10868b2c898d.jpg
#   inflating: trial/Annotated/test/images/ezgif-frame-060_png.rf.32bbf6dc24964877d12fbe0b2960d0bb.jpg
#   inflating: trial/Annotated/test/images/ezgif-frame-071_png.rf.95538280a637bb9948e21b6ffa5df3dd.jpg
# ...

# %%
import cv2
import os

def extract_frames(video_path, output_folder, num_frames):
    # Create output folder if it doesn't exist
    if not os.path.exists(output_folder):
        os.makedirs(output_folder)

    # Open the video file
    cap = cv2.VideoCapture(video_path)
    total_frames = int(cap.get(cv2.CAP_PROP_FRAME_COUNT))

    # Calculate frame extraction interval
    interval = max(total_frames // num_frames, 1)

    # Extract frames
    frame_count = 0
    while True:
        ret, frame = cap.read()
        if not ret:
            break

        if frame_count % interval == 0:
            # Save the frame
            frame_path = os.path.join(output_folder, f"frame_{frame_count}.jpg")
            cv2.imwrite(frame_path, frame)

        frame_count += 1

    # Release the video object
    cap.release()


def extract_all_frames(video_path, output_folder):
    # Create output folder if it doesn't exist
    if not os.path.exists(output_folder):
        os.makedirs(output_folder)

    # Open the video file
    cap = cv2.VideoCapture(video_path)
    total_frames = int(cap.get(cv2.CAP_PROP_FRAME_COUNT))

    # Extract frames
    frame_count = 0
    while True:
        ret, frame = cap.read()
        if not ret:
            break

        # Save the frame
        frame_path = os.path.join(output_folder, f"frame_{frame_count}.jpg")
        cv2.imwrite(frame_path, frame)

        frame_count += 1

    # Release the video object
    cap.release()

# %%
input_video_path = "/content/trial/madrid vs city.mp4"
output_folder = "/content/extracted-frames"
num_frames = 100  # Number of frames you want to extract

extract_frames(input_video_path, output_folder, num_frames)

# %%
input_video_path = "/content/trial/madrid vs city.mp4"
output_folder = "/content/extracted-all-frames"
num_frames = 100  # Number of frames you want to extract

extract_all_frames(input_video_path, output_folder)
